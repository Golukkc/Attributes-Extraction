# %%
import pandas as pd
import requests
from urllib.parse import urlparse
from PIL import Image
import google.generativeai as genai
import google.ai.generativelanguage as glm
from collections import Counter

# %%
API_KEY = 'AIzaSyDGq4q8M-MIF4CVktcDnovUhYi6_V9LN24'
genai.configure(api_key=API_KEY)
csv_file = "BSC.csv"
df = pd.read_csv(csv_file)

# %%
# df['additional_image_links'] = df['additional_image_link'].str.split(',')


# for i in range(df['additional_image_links'].apply(len).max()):
#     df[f'additional_image_link_{i+1}'] = df['additional_image_links'].apply(lambda x: x[i] if len(x) > i else None)

# %%
df.head()
# Out:
#       Product ID                 Brand  Sub brand      Product USPs Gender  \
# 0  8163382132899  Bombay Shirt Company        NaN      Wrinkle Free    Men
# 1  8058894090403  Bombay Shirt Company        NaN      Wrinkle Free    Men
# 2  8163390193827  Bombay Shirt Company        NaN      Wrinkle Free    Men
# 3  8163383771299  Bombay Shirt Company        NaN      Wrinkle Free    Men
# 4  8020691714211  Bombay Shirt Company        NaN  Soft, Breathable    Men
#
#    Print  Product Type             Material/Fabric            Collar type  \
# 0  Solid  Formal Shirt  Bamboo-poly Blended Fabric  Prince Charlie Collar
# 1  Solid        Formal                      Cotton          Madmen Collar
# 2  Solid        Formal  Bamboo-poly Blended Fabric          Spread Collar
# 3  Solid        Formal                bamboo blend          Spread Collar
# 4  Solid        Casual                       Linen            Polo Collar
#
#       Fit Sleeve Type       Color           Cuffs Type  Size  \
# 0  Custom        Full       White  Single Button Cuffs   NaN
# 1  Custom        Full       White  Double Button Cuffs   NaN
# 2  Custom        Full        Navy  Single Button Cuffs   NaN
# 3  Custom        Full  Light Blue    Double Bond Cuffs   NaN
# 4  Custom        Full       White  Single Button Cuffs   NaN
#
#                                           image_link  \
# 0  https://res.cloudinary.com/xplanck/image/fetch...
# 1  https://res.cloudinary.com/xplanck/image/fetch...
# 2  https://res.cloudinary.com/xplanck/image/fetch...
# 3  https://res.cloudinary.com/xplanck/image/fetch...
# 4  https://res.cloudinary.com/xplanck/image/fetch...
#
#                                additional_image_link  \
# 0  https://cdn.shopify.com/s/files/1/0536/3594/05...
# 1  https://cdn.shopify.com/s/files/1/0536/3594/05...
# 2  https://cdn.shopify.com/s/files/1/0536/3594/05...
# 3  https://cdn.shopify.com/s/files/1/0536/3594/05...
# 4  https://cdn.shopify.com/s/files/1/0536/3594/05...
#
#                                       custom_label_4  \
# 0  ,Back-No Pleats,Back_No Pleats,Big-Checked-Fal...
# 1  ,Back-No Pleats,Back_No Pleats,Big-Checked-Fal...
# 2  ,Back-No Pleats,Back_No Pleats,Big-Checked-Fal...
# 3  ,Back-No Pleats,Back_No Pleats,Big-Checked-Fal...
# 4  ,Back-No Pleats,Back_No Pleats,Big-Checked-Fal...
#
#                                       title  \
# 0        Wrinkle Free Durafrost Twill Shirt
# 1  Luthai Wrinkle Free Gossamer Dobby Shirt
# 2              Wrinkle Free Eon Twill Shirt
# 3         Wrinkle Free Everlast Twill Shirt
# 4                    Pearl Soft Linen Shirt
#
#                                          description
# 0                                                  .
# 1                                                  .
# 2                                                  .
# 3                                                  .
# 4  Made with a blended linen-lyocell fabric, this...

# %%
# df.drop(columns=['additional_image_link', 'additional_image_links'], inplace=True)

# %%
# Extract unique values from columns
# collar_types = df['Collar type'].unique().tolist()
# fits = df['Fit'].unique().tolist()
# sleeve_types = df['Sleeve Type'].unique().tolist()
# usps = df['Product USPs'].unique().tolist()
# genders = df['Gender'].unique().tolist()
# prints = df['Print'].unique().tolist()
# product_types = df['Product Type'].unique().tolist()
# materials = df['Material/Fabric'].unique().tolist()

# %%
# Create prompt template
# Collar type: {collar_types_str}
# Fit: {fits_str}
# Sleeve type: {sleeve_types_str}
# Product USPs: {usps_str}
# Gender: {genders_str}
# Print: {prints_str}
# Product Type: {product_types_str}
# Material/Fabric: {materials_str}
prompt_template = """Analyze the provided title and description, and identify the following attributes in an easy-to-read Excel format. The possible values for each attribute are listed:




| Attribute             | Predicted Value |
|-----------------------|-----------------|
| Collar type           |                 |
| Fit                   |                 |
| Sleeve type           |                 |
| Cuffs type            |                 |
| Color                 |                 |
| Product USPs          |                 |
| Gender                |                 |
| Print                 |                 |
| Product Type          |                 |
| Material/Fabric       |                 |
"""

# %%
# Fill prompt template with unique values
prompt = prompt_template
# .format(
#     collar_types_str=', '.join(collar_types),
#     fits_str=', '.join(fits),
#     sleeve_types_str=', '.join(sleeve_types),
#     usps_str=', '.join(usps),
#     genders_str=', '.join(genders),
#     prints_str=', '.join(prints),
#     product_types_str=', '.join(product_types),
#     materials_str=', '.join(materials)
# )

# %%
model = genai.GenerativeModel('gemini-1.0-pro')

# %%
# def generate_completion(prompt):
#     response = model.generate(prompt, max_tokens=50)
#     return response.choices[0].text.strip()

# %%
# def download_image(url, filename):
#     response = requests.get(url)
#     if response.status_code == 200:
#         with open(filename, 'wb') as f:
#             f.write(response.content)
#         return filename
#     else:
#         print(f"Failed to download image from {url}")
#         return None

# %%
# Function to process text and generate analysis
def process_title_desc(title, description):
    # Construct the parts for analysis
    parts = [
        glm.Part(text=prompt_template),
        glm.Part(text=title),
        glm.Part(text=description)
    ]
    
    # Generate content using the model
    response = model.generate_content(glm.Content(parts=parts), stream=True)
    response.resolve()
    
    return response.text

# %%
def extract_attributes(analysis_result):
    attributes = {}
    lines = analysis_result.split("\n")
    for line in lines[2:]:
        if "|" in line:
            attribute, value = line.split("|")[1:3]
            attributes[attribute.strip()] = value.strip()
    return attributes

# %%
# Apply processing to DataFrame
df['analysis_result'] = df.apply(lambda row: process_title_desc(row['title'], row['custom_label_4']), axis=1)

# %%
df['attributes'] = df['analysis_result'].apply(extract_attributes)

# %%
df['Collar type(Predicted)'] = df['attributes'].apply(lambda x: x.get('Collar type', ''))
df['Fit(Predicted)'] = df['attributes'].apply(lambda x: x.get('Fit', ''))
df['Sleeve Type(Predicted)'] = df['attributes'].apply(lambda x: x.get('Sleeve type', ''))
df['Cuffs type(Predicted)'] = df['attributes'].apply(lambda x: x.get('Cuffs type', ''))
df['Color(Predicted)'] = df['attributes'].apply(lambda x: x.get('Color', ''))
df['Product USPs(Predicted)'] = df['attributes'].apply(lambda x: x.get('Product USPs', ''))
df['Gender(Predicted)'] = df['attributes'].apply(lambda x: x.get('Gender', ''))
df['Print(Predicted)'] = df['attributes'].apply(lambda x: x.get('Print', ''))
df['Product Type(Predicted)'] = df['attributes'].apply(lambda x: x.get('Product Type', ''))
df['Material/Fabric(Predicted)'] = df['attributes'].apply(lambda x: x.get('Material/Fabric', ''))

# %%
df.head()
# Out:
#       Product ID                 Brand  Sub brand      Product USPs Gender  \
# 0  8163382132899  Bombay Shirt Company        NaN      Wrinkle Free    Men
# 1  8058894090403  Bombay Shirt Company        NaN      Wrinkle Free    Men
# 2  8163390193827  Bombay Shirt Company        NaN      Wrinkle Free    Men
# 3  8163383771299  Bombay Shirt Company        NaN      Wrinkle Free    Men
# 4  8020691714211  Bombay Shirt Company        NaN  Soft, Breathable    Men
#
#    Print  Product Type             Material/Fabric            Collar type  \
# 0  Solid  Formal Shirt  Bamboo-poly Blended Fabric  Prince Charlie Collar
# 1  Solid        Formal                      Cotton          Madmen Collar
# 2  Solid        Formal  Bamboo-poly Blended Fabric          Spread Collar
# 3  Solid        Formal                bamboo blend          Spread Collar
# 4  Solid        Casual                       Linen            Polo Collar
#
#       Fit  ... Collar type(Predicted) Fit(Predicted) Sleeve Type(Predicted)  \
# 0  Custom  ...         Prince Charlie        Regular
# 1  Custom  ...          Madmen Collar        Regular            Full Sleeve
# 2  Custom  ...          Spread Collar    Regular Fit            Long Sleeve
# 3  Custom  ...          Spread Collar        Regular            Long Sleeve
# 4  Custom  ...
#
#    Cuffs type(Predicted) Color(Predicted)    Product USPs(Predicted)  \
# 0     Single Button Cuff            White    Wrinkle Free, Durafrost
# 1     Double Button Cuff            White  Wrinkle Free, 100% Cotton
# 2     Single Button Cuff             Navy               Wrinkle Free
# 3     Double Button Cuff       Light Blue               Wrinkle Free
# 4
#
#   Gender(Predicted) Print(Predicted) Product Type(Predicted)  \
# 0      Not provided     Not provided                   Shirt
# 1               N/A              N/A                   Shirt
# 2              Male        Checkered                   Shirt
# 3      Not Provided     Not Provided                   Shirt
# 4
#
#            Material/Fabric(Predicted)
# 0  50% Bamboo 47%Polyester 3% Spandex
# 1                              Cotton
# 2           Bamboo blend/Wrinkle Free
# 3                        Bamboo Blend
# 4
#
# [5 rows x 31 columns]

# %%
# Combine original attributes into a single column
df['Original Attributes'] = df.apply(lambda row: f"Collar type: {row['Collar type']}, Fit: {row['Fit']}, Sleeve type: {row['Sleeve Type']}, Cuffs type: {row['Cuffs Type']}, Color: {row['Color']}, Product USPs: {row['Product USPs']}, Gender: {row['Gender']}, Print: {row['Print']}, Product Type: {row['Product Type']}, Material/Fabric: {row['Material/Fabric']}", axis=1)

# Combine predicted attributes into a single column
df['Predicted Attributes'] = df.apply(lambda row: f"Collar type: {row['Collar type(Predicted)']}, Fit: {row['Fit(Predicted)']}, Sleeve type: {row['Sleeve Type(Predicted)']}, Cuffs type: {row['Cuffs type(Predicted)']}, Color: {row['Color(Predicted)']}, Product USPs: {row['Product USPs(Predicted)']}, Gender: {row['Gender(Predicted)']}, Print: {row['Print(Predicted)']}, Product Type: {row['Product Type(Predicted)']}, Material/Fabric: {row['Material/Fabric(Predicted)']}", axis=1)

# %%
df.head()
# Out:
#       Product ID                 Brand  Sub brand      Product USPs Gender  \
# 0  8163382132899  Bombay Shirt Company        NaN      Wrinkle Free    Men
# 1  8058894090403  Bombay Shirt Company        NaN      Wrinkle Free    Men
# 2  8163390193827  Bombay Shirt Company        NaN      Wrinkle Free    Men
# 3  8163383771299  Bombay Shirt Company        NaN      Wrinkle Free    Men
# 4  8020691714211  Bombay Shirt Company        NaN  Soft, Breathable    Men
#
#    Print  Product Type             Material/Fabric            Collar type  \
# 0  Solid  Formal Shirt  Bamboo-poly Blended Fabric  Prince Charlie Collar
# 1  Solid        Formal                      Cotton          Madmen Collar
# 2  Solid        Formal  Bamboo-poly Blended Fabric          Spread Collar
# 3  Solid        Formal                bamboo blend          Spread Collar
# 4  Solid        Casual                       Linen            Polo Collar
#
#       Fit  ... Sleeve Type(Predicted) Cuffs type(Predicted) Color(Predicted)  \
# 0  Custom  ...                           Single Button Cuff            White
# 1  Custom  ...            Full Sleeve    Double Button Cuff            White
# 2  Custom  ...            Long Sleeve    Single Button Cuff             Navy
# 3  Custom  ...            Long Sleeve    Double Button Cuff       Light Blue
# 4  Custom  ...
#
#      Product USPs(Predicted) Gender(Predicted) Print(Predicted)  \
# 0    Wrinkle Free, Durafrost      Not provided     Not provided
# 1  Wrinkle Free, 100% Cotton               N/A              N/A
# 2               Wrinkle Free              Male        Checkered
# 3               Wrinkle Free      Not Provided     Not Provided
# 4
#
#   Product Type(Predicted)          Material/Fabric(Predicted)  \
# 0                   Shirt  50% Bamboo 47%Polyester 3% Spandex
# 1                   Shirt                              Cotton
# 2                   Shirt           Bamboo blend/Wrinkle Free
# 3                   Shirt                        Bamboo Blend
# 4
#
#                                  Original Attributes  \
# 0  Collar type: Prince Charlie Collar, Fit: Custo...
# 1  Collar type: Madmen Collar, Fit: Custom, Sleev...
# 2  Collar type: Spread Collar, Fit: Custom, Sleev...
# 3  Collar type: Spread Collar, Fit: Custom, Sleev...
# 4  Collar type: Polo Collar, Fit: Custom, Sleeve ...
#
#                                 Predicted Attributes
# 0  Collar type: Prince Charlie, Fit: Regular, Sle...
# 1  Collar type: Madmen Collar, Fit: Regular, Slee...
# 2  Collar type: Spread Collar, Fit: Regular Fit, ...
# 3  Collar type: Spread Collar, Fit: Regular, Slee...
# 4  Collar type: , Fit: , Sleeve type: , Cuffs typ...
#
# [5 rows x 33 columns]

# %%
output_csv = "output_file_Title_Desc.csv"
df.to_csv(output_csv, index=False)
